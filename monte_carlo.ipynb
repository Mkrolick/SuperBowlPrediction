# %%
# afc.csv dataset

import pandas as pd
import numpy as np
import random

# Read the data
df = pd.read_csv('afc.csv')



teams = []
for i in range(len(df)):
    offensive = df.iloc[i]['OSRS']
    defensive = df.iloc[i]['DSRS']
    team = df.iloc[i]['Tm']
    
    teams += [[team, offensive, defensive]]



simulations = []
for i in range(10000):
    # create a list of 16 games
    games = []
    for j in range(16):
        # pick 2 teams randomly
        team1 = random.choice(teams)
        team2 = random.choice(teams)
        # calculate the score
        score1 = team1[1] + team2[2]
        score2 = team2[1] + team1[2]
        # add the game to the list
        games.append([team1[0], team2[0], score1, score2])
    # add the list of games to the list of simulations
    simulations.append(games)


# create a dictionary of teams
teams_dict = {}
for full_team in teams:
    teams_dict[full_team[0]] = 0

# loop through the simulations
for simulation in simulations:
    # loop through the games
    for game in simulation:
        # check if team1 won
        if game[2] > game[3]:
            teams_dict[game[0]] += 1
        # check if team2 won
        elif game[2] < game[3]:
            teams_dict[game[1]] += 1
        # check if it was a tie
        else:
            teams_dict[game[0]] += 0.5
            teams_dict[game[1]] += 0.5

    
# 4. print the results

print('Ranking of the teams:')
for team in sorted(teams_dict, key=teams_dict.get, reverse=True):
    print(team, teams_dict[team])
# Out:
# Ranking of the teams:
# Detroit Lions 19307.0
# Minnesota Vikings* 18183.0
# Philadelphia Eagles* 16678.0
# Seattle Seahawks+ 15757.0
# Dallas Cowboys+ 14268.0
# Arizona Cardinals 12945.0
# Atlanta Falcons 11918.0
# Chicago Bears 10677.0
# Carolina Panthers 9248.0
# Green Bay Packers 8239.0
# New York Giants+ 7013.0
# San Francisco 49ers* 5663.0
# Los Angeles Rams 4351.0
# Tampa Bay Buccaneers* 3206.0
# New Orleans Saints 1923.0
# Washington Commanders 624.0

# %%
# afc.csv dataset

import pandas as pd
import numpy as np
import random

# Read the data
df = pd.read_csv('heart.csv')



teams = []
for i in range(len(df)):
    offensive = df.iloc[i]['OSRS']
    defensive = df.iloc[i]['DSRS']
    team = df.iloc[i]['Tm']
    
    teams += [[team, offensive, defensive]]


simulations = []
for i in range(10000):
    # create a list of 16 games
    games = []
    for j in range(16):
        # pick 2 teams randomly
        team1 = random.choice(teams)
        team2 = random.choice(teams)
        # calculate the score
        score1 = team1[1] + team2[2]
        score2 = team2[1] + team1[2]
        # add the game to the list
        games.append([team1[0], team2[0], score1, score2])
    # add the list of games to the list of simulations
    simulations.append(games)



# create a dictionary of teams
teams_dict = {}
for full_team in teams:
    teams_dict[full_team[0]] = 0

# loop through the simulations
for simulation in simulations:
    # loop through the games
    for game in simulation:
        # check if team1 won
        if game[2] > game[3]:
            teams_dict[game[0]] += 1
        # check if team2 won
        elif game[2] < game[3]:
            teams_dict[game[1]] += 1
        # check if it was a tie
        else:
            teams_dict[game[0]] += 0.5
            teams_dict[game[1]] += 0.5

    
# 4. print the results

print('Ranking of the teams:')
for team in sorted(teams_dict, key=teams_dict.get, reverse=True):
    print(team, teams_dict[team])
# Out:
# Ranking of the teams:
# Kansas City Chiefs* 19519.0
# Las Vegas Raiders 17984.0
# Cincinnati Bengals* 16994.0
# Miami Dolphins+ 15578.0
# Buffalo Bills* 14392.0
# Cleveland Browns 13097.0
# Jacksonville Jaguars* 11955.0
# Los Angeles Chargers+ 10627.0
# Indianapolis Colts 9341.0
# Houston Texans 8089.0
# New England Patriots 6886.0
# Baltimore Ravens+ 5626.0
# Pittsburgh Steelers 4317.0
# Tennessee Titans 3013.0
# Denver Broncos 1900.0
# New York Jets 682.0
